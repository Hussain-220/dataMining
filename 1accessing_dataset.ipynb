# %%
import pandas as pd

# %% [markdown]
# ###1. Importing from local disk

# %%
from google.colab import files

# upload the dataset
uploaded = files.upload()

# getting the filename
filename = list(uploaded.keys())[0]

# load CSV into Pandas DataFrame
df = pd.read_csv(filename)
print(df.head())  # display first few rows
# Out:
#      <input type="file" id="files-b58fb571-84bc-44c8-894a-3fdbefae4717" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b58fb571-84bc-44c8-894a-3fdbefae4717">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ###2. Importing from Colab's Disk

# %%
# !ls
# Out:
# 'Dataset Inside'   mnist_test.csv   sample_data

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    Unnamed: 0      id  price  category    size  availability      date  \
# 0       63575  HP9426   60.0  sneakers      36             0  7/1/2025
# 1       63576  HP9426   60.0  sneakers  36 2/3             0  7/1/2025
# 2       63577  HP9426   60.0  sneakers  37 1/3             0  7/1/2025
# 3       63578  HP9426   60.0  sneakers      38             0  7/1/2025
# 4       63579  HP9426   60.0  sneakers  38 2/3             1  7/1/2025
#
#   country_code
# 0           DE
# 1           DE
# 2           DE
# 3           DE
# 4           DE

# %% [markdown]
# ###3. Importing from Google Drive

# %%
from google.colab import drive

# %%
# mount G-Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##### Force Remount

# %%
# Out:
# Mounted at /content/drive

# %%
# File path (Modify as per your Google Drive structure)
file_path = "/content/drive/My Drive/Datasets/shoes_fact.csv"

# Load dataset
df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0      id  price  category    size  availability      date  \
# 0       63575  HP9426   60.0  sneakers      36             0  7/1/2025
# 1       63576  HP9426   60.0  sneakers  36 2/3             0  7/1/2025
# 2       63577  HP9426   60.0  sneakers  37 1/3             0  7/1/2025
# 3       63578  HP9426   60.0  sneakers      38             0  7/1/2025
# 4       63579  HP9426   60.0  sneakers  38 2/3             1  7/1/2025
#
#   country_code
# 0           DE
# 1           DE
# 2           DE
# 3           DE
# 4           DE

# %% [markdown]
# ###4. Importing from a GitHub Repository

# %% [markdown]
# ##### a. downloading a specific file/dataset

# %%
# URL of the raw CSV file from GitHub
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

# %%
df = pd.read_csv(url)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ##### b. cloning a GitHub repository

# %%
# !git clone https://github.com/datasets/covid-19.git # clone a complete repository
# Out:
# Cloning into 'covid-19'...
# remote: Enumerating objects: 9182, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 9182 (delta 13), reused 20 (delta 8), pack-reused 9149 (from 1)
# Receiving objects: 100% (9182/9182), 4.98 GiB | 22.43 MiB/s, done.
# Resolving deltas: 100% (7058/7058), done.
# Updating files: 100% (16/16), done.

# %%
df = pd.read_csv("/content/covid-19/data/countries-aggregated.csv")
print(df.head())
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-23  Afghanistan          0          0       0
# 2  2020-01-24  Afghanistan          0          0       0
# 3  2020-01-25  Afghanistan          0          0       0
# 4  2020-01-26  Afghanistan          0          0       0

# %%
df.tail()
# Out:
#               Date   Country  Confirmed  Recovered  Deaths
# 161563  2022-04-12  Zimbabwe     247094          0    5460
# 161564  2022-04-13  Zimbabwe     247160          0    5460
# 161565  2022-04-14  Zimbabwe     247208          0    5462
# 161566  2022-04-15  Zimbabwe     247237          0    5462
# 161567  2022-04-16  Zimbabwe     247237          0    5462
